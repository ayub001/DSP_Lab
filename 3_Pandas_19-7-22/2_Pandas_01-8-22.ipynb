# %%
#Python | pandas

# %%
import pandas as pd
import numpy as np

# %%
a = pd.Series([10,20,30]),

a
# Out:
# (0    10
#  1    20
#  2    30
#  dtype: int64,)

# %%
b = pd.Series(["xyz","abc","ghi"])

b
# Out:
# 0    xyz
# 1    abc
# 2    ghi
# dtype: object

# %%
di = {"Name":['xyz','abc','ghi'],"Roll.No":[123,456,923]}

df = pd.DataFrame(di)

df
# Out:
#   Name  Roll.No
# 0  xyz      123
# 1  abc      456
# 2  ghi      923

# %%
di = {'color':['Red','blue'],'type':['apple','sky']}

s = pd.DataFrame(di)

s
# Out:
#   color   type
# 0   Red  apple
# 1  blue    sky

# %%
d = pd.read_csv("SMS-Data.csv")

df = pd.DataFrame(d)

df
# Out:
#        phoneNumber                                    id  \
# 0       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 1       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 2       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 3       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 4       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# ...            ...                                   ...
# 100238  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100239  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100240  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100241  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100242  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
#
#                             updateAt  senderAddress  \
# 0       Sat, 7 May 2022 19:48:00 UTC      JK-SmplPL
# 1       Sat, 7 May 2022 19:48:00 UTC      VP-ViCARE
# 2       Sat, 7 May 2022 19:48:00 UTC      VP-612345
# 3       Sat, 7 May 2022 19:48:00 UTC      BP-ACKOGI
# ...

# %%
df.head()
# Out:
#   phoneNumber                                    id  \
# 0  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 1  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 2  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 3  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 4  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
#
#                        updateAt senderAddress  \
# 0  Sat, 7 May 2022 19:48:00 UTC     JK-SmplPL
# 1  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
# 2  Sat, 7 May 2022 19:48:00 UTC     VP-612345
# 3  Sat, 7 May 2022 19:48:00 UTC     BP-ACKOGI
# 4  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
#
#                                                 text
# 0  Rs.95.15 on Zomato charged via Simpl.\r\n--\r\...
# 1  Hi! Update your email id through WhatsApp: htt...
# 2  Lucknow ya Kolkata ? - watch it LIVE with Vi c...
# 3  Mohd,\nCheck the incredible Acko insurance pol...
# 4  Hi! You can now get your Vi prepaid invoice em...

# %%
df.tail()
# Out:
#        phoneNumber                                    id  \
# 100238  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100239  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100240  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100241  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100242  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
#
#                             updateAt  senderAddress  \
# 100238  Wed, 4 May 2022 07:14:44 UTC      JD-AKAMAH
# 100239  Wed, 4 May 2022 07:14:44 UTC  +917986412509
# 100240  Wed, 4 May 2022 07:14:44 UTC  +919417271313
# 100241  Wed, 4 May 2022 07:14:44 UTC  +917986412509
# 100242  Wed, 4 May 2022 07:14:44 UTC  +917986412509
#
#                                                      text
# 100238  As we celebrate Azadi Ka Amrit Mahotsav, let's...
# 100239  Dear Customer, +917986412509 is now available ...
# 100240  Dear Customer, +919417271313 is now available ...
# 100241  Dear Customer, +917986412509 is now available ...
# ...

# %%
df.head(10)
# Out:
#   phoneNumber                                    id  \
# 0  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 1  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 2  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 3  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 4  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 5  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 6  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 7  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 8  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 9  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
#
#                        updateAt senderAddress  \
# 0  Sat, 7 May 2022 19:48:00 UTC     JK-SmplPL
# 1  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
# 2  Sat, 7 May 2022 19:48:00 UTC     VP-612345
# 3  Sat, 7 May 2022 19:48:00 UTC     BP-ACKOGI
# 4  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
# 5  Sat, 7 May 2022 19:48:00 UTC     TM-BYJUSC
# 6  Sat, 7 May 2022 19:48:00 UTC     VP-611123
# ...

# %%
df.tail(10)
# Out:
#        phoneNumber                                    id  \
# 100233  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100234  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100235  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100236  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100237  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100238  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100239  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100240  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100241  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100242  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
#
#                             updateAt  senderAddress  \
# 100233  Wed, 4 May 2022 07:14:44 UTC  +919417271313
# 100234  Wed, 4 May 2022 07:14:44 UTC       56161940
# 100235  Wed, 4 May 2022 07:14:44 UTC      JD-JIOINF
# 100236  Wed, 4 May 2022 07:14:44 UTC      AD-KJRIWL
# 100237  Wed, 4 May 2022 07:14:44 UTC  +917986412509
# ...

# %%
df.describe()
# Out:
#        phoneNumber                                    id  \
# count       100243                                100243
# unique          93                                    93
# top     xx31026369  72b90e8a-1960-44f6-9bfc-a19a9410bd47
# freq          7880                                  7880
#
#                              updateAt senderAddress  \
# count                          100243        100243
# unique                            138          8929
# top     Wed, 11 May 2022 09:50:29 UTC     TX-SFXRDR
# freq                             2001          3401
#
#                                                      text
# count                                              100237
# unique                                              59377
# top     We are unable to get your location. Location i...
# freq                                                 1151

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100243 entries, 0 to 100242
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   phoneNumber    100243 non-null  object
#  1   id             100243 non-null  object
#  2   updateAt       100243 non-null  object
#  3   senderAddress  100243 non-null  object
#  4   text           100237 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB

# %%
df["id"]
# Out:
# 0         baa1668c-049e-4118-938e-cc804f1e73aa
# 1         baa1668c-049e-4118-938e-cc804f1e73aa
# 2         baa1668c-049e-4118-938e-cc804f1e73aa
# 3         baa1668c-049e-4118-938e-cc804f1e73aa
# 4         baa1668c-049e-4118-938e-cc804f1e73aa
#                           ...
# 100238    3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100239    3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100240    3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100241    3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100242    3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# Name: id, Length: 100243, dtype: object

# %%
a = pd.read_csv("SMS-Data.csv")

p = pd.DataFrame(a)

p
# Out:
#        phoneNumber                                    id  \
# 0       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 1       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 2       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 3       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 4       xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# ...            ...                                   ...
# 100238  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100239  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100240  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100241  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
# 100242  xx86412509  3d368683-a2a5-4c96-88c0-8c7a3ac8bdc5
#
#                             updateAt  senderAddress  \
# 0       Sat, 7 May 2022 19:48:00 UTC      JK-SmplPL
# 1       Sat, 7 May 2022 19:48:00 UTC      VP-ViCARE
# 2       Sat, 7 May 2022 19:48:00 UTC      VP-612345
# 3       Sat, 7 May 2022 19:48:00 UTC      BP-ACKOGI
# ...

# %%
print(df.loc[4])
# Out:
# phoneNumber                                             xx39973810
# id                            baa1668c-049e-4118-938e-cc804f1e73aa
# updateAt                              Sat, 7 May 2022 19:48:00 UTC
# senderAddress                                            VP-ViCARE
# text             Hi! You can now get your Vi prepaid invoice em...
# Name: 4, dtype: object

# %%
df.loc[1,"phoneNumber"]
# Out:
# 'xx39973810'

# %%
data = pd.read_csv("data.csv")

df = pd.DataFrame(data)

df
# Out:
#     Rank             Username                  Owner  Followers (millions)  \
# 0      1           @instagram              Instagram                 515.0
# 1      2           @cristiano      Cristiano Ronaldo                 450.0
# 2      3         @kyliejenner           Kylie Jenner                 344.0
# 3      4            @leomessi           Lionel Messi                 333.0
# 4      5         @selenagomez           Selena Gomez                 324.0
# 5      6             @therock         Dwayne Johnson                 320.0
# 6      7       @kimkardashian         Kim Kardashian                 316.0
# 7      8        @arianagrande          Ariana Grande                 314.0
# 8      9             @beyonce          Ariana Grande                 261.0
# 9     10     @khloekardashian        Khlo Kardashian                 249.0
# 10    11       @kendalljenner         Kendall Jenner                 240.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  50 non-null     int64
#  1   Username              50 non-null     object
#  2   Owner                 50 non-null     object
#  3   Followers (millions)  50 non-null     float64
#  4   Profession/Activity   50 non-null     object
#  5   Country/Continent     50 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],'Max Speed': [380.,370.,24.,26.,]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
arrays = [['Falcon','Falcon','Parrot','Parrot'],['Captive','Wild','Captive','Wild']]

index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type') )
df = pd.DataFrame({'Max Speed': [390.,350.,30.,20.]}, index=index)
df
# Out:
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %%
df.groupby(level=0).mean()
# Out:
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0

# %%
df.groupby(level='Type').mean()
# Out:
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0

# %%
l = [[1,2,3],[1, None, 4],[2,1,3],[1,2,2]]
df = pd.DataFrame(l, columns=['a','b','c'])

# %%
df.groupby(by=['b']).sum()
# Out:
#      a  c
# b
# 1.0  2  3
# 2.0  2  5

# %%
df.groupby(by=['b'], dropna=False).sum()
# Out:
#      a  c
# b
# 1.0  2  3
# 2.0  2  5
# NaN  1  4

# %%
df.groupby(by='a').sum()
# Out:
#      b  c
# a
# 1  4.0  9
# 2  1.0  3

# %%
df.groupby(by='a', dropna=False).sum()
# Out:
#      b  c
# a
# 1  4.0  9
# 2  1.0  3
